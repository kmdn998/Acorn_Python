# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Flatten, Input, concatenate
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import tensorflow.keras.utils as utils
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score

from tensorflow.keras.datasets import mnist

# %% [markdown]
# ## 1

# %%
import tensorflow as tf
import seaborn as sns

# Iris 데이터셋 로드
iris = sns.load_dataset("iris")

# 입력 데이터 및 레이블 분리
X = iris.drop('species', axis=1)
y = iris['species']

# 레이블을 원-핫 인코딩
y_encoded = pd.get_dummies(y)

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(4, )))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X, y_encoded, epochs=10, batch_size=32)

y_pred = model.predict(X)

print(y_pred)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 1s 1ms/step - loss: 1.0634 - accuracy: 0.4400
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9370 - accuracy: 0.5467
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8563 - accuracy: 0.6667
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7775 - accuracy: 0.7000
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7020 - accuracy: 0.8933
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.8333
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5537 - accuracy: 0.8600
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4912 - accuracy: 0.9067
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.9667
# Epoch 10/10
# ...
# 5/5 [==============================] - 0s 1ms/step
# ...

# %% [markdown]
# ## 2

# %%
from sklearn.model_selection import KFold

# Iris 데이터셋 로드
iris = sns.load_dataset("iris")

# 입력 데이터 및 레이블 분리
X = iris.drop('species', axis=1)
y = iris['species']

# 레이블을 원-핫 인코딩
y_encoded = pd.get_dummies(y)

kfold = KFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []
for train_index, test_index in kfold.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y_encoded.iloc[train_index], y_encoded.iloc[test_index]

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(64, activation='relu', input_shape=(4, )))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    _, accuracy = model.evaluate(X_test, y_test)
    accuracies.append(accuracy)
# Out:
# ...
# 1/1 [==============================] - 0s 99ms/step - loss: 0.5056 - accuracy: 0.8333
# WARNING:tensorflow:5 out of the last 5004 calls to <function Model.make_test_function.<locals>.test_function at 0x000001A68FB44820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 94ms/step - loss: 0.5067 - accuracy: 0.9333
# ...

# %% [markdown]
# # 1. 특징
#
# - 프레임워크 ( vs 모듈): 환경을 만들어줌
# - DL, ML 프레임워크
#     - Theano
#     - Pytorch
#     - Keras
#     - NLTK
#     - Caffe
#     - ...
# - Tensorflow: 구글에서 만든 오픈소스 프레임워크
# - 다양한 언어를 제공하며 그중에서 파이썬이 가장 많이 사용됨
# - 기본적으로 텐서를 활용한 그래프 수치 연산을 하는 도구
# - 1.x 버전에서 2.x버전으로 업그레이드
# - 고차원 수준의 API로 keras 사용
# - https://www.tensorflow.org/?hl=ko

# %% [markdown]
# # 2. 가상환경
# - 가상환경 리스트 확인
#     - conda info --envs
# - conda create -n 가상환경이름
#     - conda create -n tf1 python=3.7 anaconda
#         - (conda init cmd.exe)
#         - conda activate vitrual1
#         - pip install tensorflow==1.15
#         - pip install --upgrade protobuf==3.20
#
# - 가상 환경 전환
#     - conda activate 가상환경이름
#     - conda deactive
#
# - 가상 환경 삭제
#     - conda remove --name 가상환경이름 --all
#
#
# python --version # 3.9
#
# conda activate tf1
# python --version # 3.7
#
# cd\ jupyternotebook

# %%
import tensorflow as tf

# X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2001):
   sess.run(train)
   if step % 20 == 0:
       print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:7: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:17: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:21: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:23: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 0 7.4605985 [0.6145799] [-1.9423803]
# 20 0.3522415 [1.523799] [-1.4590967]
# 40 0.26167035 [1.5840328] [-1.3531984]
# 60 0.23712511 [1.5646647] [-1.286049]
# 80 0.2153561 [1.5388968] [-1.225271]
# ...

# %% [markdown]
# # 3. Tensorflow 설치
#
# - pip install tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## (1) API
# - tf.data
# - tf.keras

# %% [markdown]
# ## (2) 기본 함수와 객체
# - constant(): 상수 함수. 데이터를 tensor로 바꿔줌
# - Variable(): 변수 클래스(객체)

# %%
t1= tf.constant(10)
print(t1) # tensor로 반환
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
t1= t1+5
print(t1) 
type(t1)
# Out:
# tf.Tensor(15, shape=(), dtype=int32)
# tensorflow.python.framework.ops.EagerTensor

# %%
t2= tf.constant(20)
print(t1+t2)
# Out:
# tf.Tensor(35, shape=(), dtype=int32)

# %%
t1.numpy() # tensor의 데이터만
# Out:
# 15

# %%
type(t1.numpy())
# Out:
# numpy.int32

# %%
t3= tf.constant('Helllo 가나다') # byte로 표시
print(t3)
print(t3.numpy().decode('utf-8'))
# Out:
# tf.Tensor(b'Helllo \xea\xb0\x80\xeb\x82\x98\xeb\x8b\xa4', shape=(), dtype=string)
# Helllo 가나다

# %%
t4= tf.constant([2,3,4]) # 1차원
print(t4)
# Out:
# tf.Tensor([2 3 4], shape=(3,), dtype=int32)

# %%
t5= tf.constant([[1,2,3]]) # 2차원
print(t5)
# Out:
# tf.Tensor([[1 2 3]], shape=(1, 3), dtype=int32)

# %%
a= tf.constant(tf.cast(3, dtype=float))
b= tf.constant(4.5)
a+b
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.5>

# %%
a= tf.constant(3, dtype=float)
b= tf.constant(4.5)
a+b
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.5>

# %% [markdown]
# # 4. Keras
#
# ## (1) 특징
# - 파이썬으로 구현된 쉽고 간결한 딥러닝 라이브러리
# - 구글의 엔지니어인 프랑소와 숄레가 2015년 3월 발표
# - 내부적으로는 텐서플로우 엔진이 구동되지만 직관적인 API로 쉽게 딥러닝 실험을 할 수 있도록 지원
# - https://keras.io/kr

# %% [markdown]
# ## (2) 설치
# - pip install keras

# %% [markdown]
# ## (3) API
#
# - 준비: Sequential(), Model()
# - Layer 설정: Dense()
# - 컴파일: compile()
#     - loss(cost)
#         - 선형회귀: MSE, MAE, RMSE, ...
#         - 이진분류: BCE(Binary Cross Entropy)
#         - 다중분류: CCE(Categorical Cross Entropy)
#
#     - optimizer(최소비용)
#         - SGD
#         - RMSprop
#         - Adagrad
#         - Adadelta
#         - Adam
#         - Admax
#         - Nadam
#         - ....
# - 학습: fit()
# - 평가: evaluate()
# - 예측: predict()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Machine Learning
# ## (1) 예제1
# - 1 -> 1, ... 100 -> 100. 회귀문제
# - wx + b: w=1, b=0

# %%
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam

# %%
x_train= [1,2,3]
y_train= [1,2,3] # 회귀는 활성함수 필요 없음

model= tf.keras.models.Sequential() # 박스 생성

model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear')) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD()) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 1)                 0
#
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=2000) # 2000번 학습.미분. 오차 줄어듦
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 1s/step - loss: 0.9345
# Epoch 2/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7395
# Epoch 3/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5853
# Epoch 4/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4634
# Epoch 5/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3671
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2910
# Epoch 7/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2308
# Epoch 8/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1832
# Epoch 9/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1456
# Epoch 10/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1158
# Epoch 11/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0923
# Epoch 12/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0737
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[0.99727637]], dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([0.0061914], dtype=float32)>]

# %%
# wx + b

print(model.weights[0].numpy()* x_train[0] +model.weights[1].numpy())
print(model.weights[0].numpy()* x_train[1] +model.weights[1].numpy())
print(model.weights[0].numpy()* 99 +model.weights[1].numpy())
# Out:
# [[0.9992494]]
# [[1.9998395]]
# [[99.05709]]

# %% [markdown]
# ## (2) 예제2

# %%
x= [1,2,3,4,5,6]
y= [3,4,5,6,7,8]

model= tf.keras.models.Sequential() # 박스 생성

model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear')) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=0.01)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 1)                 0
#
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0070
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2200
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3903
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0036
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8220
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7353
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6927
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6703
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6574
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6490
# Epoch 11/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6425
# Epoch 12/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6370
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.0114231]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([1.9510957], dtype=float32)>]

# %%
model.predict([4])
# Out:
# 1/1 [==============================] - 0s 126ms/step
# array([[5.996788]], dtype=float32)

# %%
import matplotlib.pyplot as plt

result.history.keys()
plt.plot(result.history['loss'])

# %% [markdown]
# ## (3) 예제3
# - 8시간 일했을 때 매출액은?

# %%
#### 매출액 예측
x= [1,2,3,4,5,6,7]
y= [25000, 55000, 75000, 110000, 128000, 155000, 180000]

# %%
model= tf.keras.models.Sequential() # 박스 생성

# model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear', input_shape=(1,))) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=0.01)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 13456406528.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4594329600.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1573459328.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 543708736.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 192679904.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 73010536.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 32205650.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 18283804.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 13525770.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 11891610.0000
# Epoch 11/1000
# ...

# %%
model.weights
# Out:
# [<tf.Variable 'dense_4/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[25627.406]], dtype=float32)>,
#  <tf.Variable 'dense_4/bias:0' shape=(1,) dtype=float32, numpy=array([1505.0852], dtype=float32)>]

# %%
model.predict([8])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[206524.33]], dtype=float32)

# %% [markdown]
# ## (4) 예제4

# %%
x= [[73, 80, 75], [93, 88, 93], [89, 91, 90], [96, 98, 100], [73, 66, 70]]
y= [[152], [185], [180], [196], [142]]

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(3,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-5)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.0114231]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([1.9510957], dtype=float32)>]

# %%
print(model.predict([[73, 80, 75]])) # 148
print(model.predict([[93, 88, 93]])) # 186
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[148.11285]]
# 1/1 [==============================] - 0s 27ms/step
# [[186.75394]]

# %%
plt.plot(result.history['loss'])

# %% [markdown]
# ## (5) 예제5
# - 체중과 나이에 따른 혈당 예측
# - 체중이 100이고 나이가 40일때 혈당은?

# %%
import numpy as np

data= np.genfromtxt('data/x09.txt', skip_header=36)
data
# Out:
# array([[  1.,   1.,  84.,  46., 354.],
#        [  2.,   1.,  73.,  20., 190.],
#        [  3.,   1.,  65.,  52., 405.],
#        [  4.,   1.,  70.,  30., 263.],
#        [  5.,   1.,  76.,  57., 451.],
#        [  6.,   1.,  69.,  25., 302.],
#        [  7.,   1.,  63.,  28., 288.],
#        [  8.,   1.,  72.,  36., 385.],
#        [  9.,   1.,  79.,  57., 402.],
#        [ 10.,   1.,  75.,  44., 365.],
#        [ 11.,   1.,  27.,  24., 209.],
#        [ 12.,   1.,  89.,  31., 290.],
#        [ 13.,   1.,  65.,  52., 346.],
#        [ 14.,   1.,  57.,  23., 254.],
#        [ 15.,   1.,  59.,  60., 395.],
#        [ 16.,   1.,  69.,  48., 434.],
#        [ 17.,   1.,  60.,  34., 220.],
#        [ 18.,   1.,  79.,  51., 374.],
#        [ 19.,   1.,  75.,  50., 308.],
#        [ 20.,   1.,  82.,  34., 220.],
#        [ 21.,   1.,  59.,  46., 311.],
#        [ 22.,   1.,  67.,  23., 181.],
#        [ 23.,   1.,  85.,  37., 274.],
#        [ 24.,   1.,  55.,  40., 303.],
# ...

# %%
x= [data[i][1:4].tolist() for i in range(len(data))]
y= [i[4].tolist() for i in data]

# %%
x= data[:, 1:4]
y= data[:, 4]

# %%
x= np.array(data[:, 1:4], dtype=np.float32)
y= np.array(data[:, 4], dtype=np.float32)

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(3,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-5)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 158ms/step - loss: 76999.1328
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 59225.6836
# Epoch 3/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 45729.9648
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 35482.0742
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 27700.0645
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 21790.2422
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 17301.8770
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 13892.7314
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 11302.9785
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9335.3467
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7840.0664
# Epoch 12/1000
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_15/kernel:0' shape=(3, 1) dtype=float32, numpy=
#  array([[-0.76722646],
#         [ 1.4772904 ],
#         [ 5.3111925 ]], dtype=float32)>,
#  <tf.Variable 'dense_15/bias:0' shape=(1,) dtype=float32, numpy=array([0.08178992], dtype=float32)>]

# %%
print(model.predict([[1, 100, 40]])) # 362
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[359.49127]]

# %%
plt.plot(result.history['loss'])

# %% [markdown]
# ## (6) 예제6

# %%
loaded_data= np.loadtxt('data/sps.csv', delimiter=',', dtype=np.float32)
loaded_data
# Out:
# array([[  1.,   1.,   1.,   2.,   1.],
#        [ 14.,   2.,  -3.,   9.,   0.],
#        [  5.,   4.,   1.,   0.,  -2.],
#        [ -4.,   3.,   2.,   1.,   6.],
#        [  3.,   5.,   1.,   8.,   9.],
#        [  3.,  -1.,   5.,   8.,  -1.],
#        [  2.,   2.,   3.,   7.,   4.],
#        [  4.,   4.,   5.,   6.,   1.],
#        [  0.,   4.,   4.,   4.,   4.],
#        [ -2.,   1.,   1.,   3.,   5.],
#        [  1.,   7.,  -2.,   1.,   9.],
#        [  0.,   9.,   0.,   0.,   9.],
#        [  0.,   2.,   1.,   1.,   2.],
#        [  0.,   3.,   3.,   3.,   3.],
#        [-11.,   1.,   4.,  -7.,   1.],
#        [ -8.,   4.,   1.,  -9.,   2.],
#        [  5.,   2.,  -2.,   2.,   1.],
#        [  0.,   3.,   3.,   2.,   2.],
#        [ -6.,   1.,   6.,   1.,   2.],
#        [  1.,   4.,   5.,   4.,   2.],
#        [ -8.,   3.,   3.,  -7.,   1.],
#        [ 16.,   8.,  -7.,   8.,   7.],
#        [  0.,   1.,   2.,  -3.,  -4.],
#        [  0.,   0.,   0.,   0.,   0.],
# ...

# %%
x= loaded_data[:, 1:]
y= loaded_data[:, 0]

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(4,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-2)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 1)                 5
#
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 40.3417
# Epoch 2/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 11.0809
# Epoch 3/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 5.3741
# Epoch 4/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7515
# Epoch 5/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3534
# Epoch 6/1000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6923
# Epoch 7/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3735
# Epoch 8/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1991
# Epoch 9/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1002
# Epoch 10/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 11/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 12/1000
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_17/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[ 1.       ],
#         [-1.0000001],
#         [ 1.       ],
#         [-1.0000001]], dtype=float32)>,
#  <tf.Variable 'dense_17/bias:0' shape=(1,) dtype=float32, numpy=array([3.5518897e-07], dtype=float32)>]

# %%
plt.plot(result.history['loss'])

# %%
print(model.predict([[45, 33, 25, 68]])) # 362
# Out:
# 1/1 [==============================] - 0s 43ms/step
# [[-31.000011]]

# %% [markdown]
# # 1. 특징
#
# - 프레임워크 ( vs 모듈): 환경을 만들어줌
# - DL, ML 프레임워크
#     - Theano
#     - Pytorch
#     - Keras
#     - NLTK
#     - Caffe
#     - ...
# - Tensorflow: 구글에서 만든 오픈소스 프레임워크
# - 다양한 언어를 제공하며 그중에서 파이썬이 가장 많이 사용됨
# - 기본적으로 텐서를 활용한 그래프 수치 연산을 하는 도구
# - 1.x 버전에서 2.x버전으로 업그레이드
# - 고차원 수준의 API로 keras 사용
# - https://www.tensorflow.org/?hl=ko

# %% [markdown]
# # 2. 가상환경
# - 가상환경 리스트 확인
#     - conda info --envs
# - conda create -n 가상환경이름
#     - conda create -n tf1 python=3.7 anaconda
#         - (conda init cmd.exe)
#         - conda activate vitrual1
#         - pip install tensorflow==1.15
#         - pip install --upgrade protobuf==3.20
#
# - 가상 환경 전환
#     - conda activate 가상환경이름
#     - conda deactive
#
# - 가상 환경 삭제
#     - conda remove --name 가상환경이름 --all
#
#
# python --version # 3.9
#
# conda activate tf1
# python --version # 3.7
#
# cd\ jupyternotebook

# %%
import tensorflow as tf

# X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Fit the line
for step in range(2001):
   sess.run(train)
   if step % 20 == 0:
       print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:7: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:17: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:21: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\acorn\AppData\Local\Temp\ipykernel_1416\808803728.py:23: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 0 7.4605985 [0.6145799] [-1.9423803]
# 20 0.3522415 [1.523799] [-1.4590967]
# 40 0.26167035 [1.5840328] [-1.3531984]
# 60 0.23712511 [1.5646647] [-1.286049]
# 80 0.2153561 [1.5388968] [-1.225271]
# ...

# %% [markdown]
# # 3. Tensorflow 설치
#
# - pip install tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## (1) API
# - tf.data
# - tf.keras

# %% [markdown]
# ## (2) 기본 함수와 객체
# - constant(): 상수 함수. 데이터를 tensor로 바꿔줌
# - Variable(): 변수 클래스(객체)

# %%
t1= tf.constant(10)
print(t1) # tensor로 반환
# Out:
# tf.Tensor(10, shape=(), dtype=int32)

# %%
t1= t1+5
print(t1) 
type(t1)
# Out:
# tf.Tensor(15, shape=(), dtype=int32)
# tensorflow.python.framework.ops.EagerTensor

# %%
t2= tf.constant(20)
print(t1+t2)
# Out:
# tf.Tensor(35, shape=(), dtype=int32)

# %%
t1.numpy() # tensor의 데이터만
# Out:
# 15

# %%
type(t1.numpy())
# Out:
# numpy.int32

# %%
t3= tf.constant('Helllo 가나다') # byte로 표시
print(t3)
print(t3.numpy().decode('utf-8'))
# Out:
# tf.Tensor(b'Helllo \xea\xb0\x80\xeb\x82\x98\xeb\x8b\xa4', shape=(), dtype=string)
# Helllo 가나다

# %%
t4= tf.constant([2,3,4]) # 1차원
print(t4)
# Out:
# tf.Tensor([2 3 4], shape=(3,), dtype=int32)

# %%
t5= tf.constant([[1,2,3]]) # 2차원
print(t5)
# Out:
# tf.Tensor([[1 2 3]], shape=(1, 3), dtype=int32)

# %%
a= tf.constant(tf.cast(3, dtype=float))
b= tf.constant(4.5)
a+b
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.5>

# %%
a= tf.constant(3, dtype=float)
b= tf.constant(4.5)
a+b
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.5>

# %% [markdown]
# # 4. Keras
#
# ## (1) 특징
# - 파이썬으로 구현된 쉽고 간결한 딥러닝 라이브러리
# - 구글의 엔지니어인 프랑소와 숄레가 2015년 3월 발표
# - 내부적으로는 텐서플로우 엔진이 구동되지만 직관적인 API로 쉽게 딥러닝 실험을 할 수 있도록 지원
# - https://keras.io/kr

# %% [markdown]
# ## (2) 설치
# - pip install keras

# %% [markdown]
# ## (3) API
#
# - 준비: Sequential(), Model()
# - Layer 설정: Dense()
# - 컴파일: compile()
#     - loss(cost)
#         - 선형회귀: MSE, MAE, RMSE, ...
#         - 이진분류: BCE(Binary Cross Entropy)
#         - 다중분류: CCE(Categorical Cross Entropy)
#
#     - optimizer(최소비용)
#         - SGD
#         - RMSprop
#         - Adagrad
#         - Adadelta
#         - Adam
#         - Admax
#         - Nadam
#         - ....
# - 학습: fit()
# - 평가: evaluate()
# - 예측: predict()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Machine Learning
# ## (1) 예제1
# - 1 -> 1, ... 100 -> 100. 회귀문제
# - wx + b: w=1, b=0

# %%
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD, Adam

# %%
x_train= [1,2,3]
y_train= [1,2,3] # 회귀는 활성함수 필요 없음

model= tf.keras.models.Sequential() # 박스 생성

model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear')) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD()) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 1)                 0
#
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=2000) # 2000번 학습.미분. 오차 줄어듦
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 1s/step - loss: 0.9345
# Epoch 2/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7395
# Epoch 3/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5853
# Epoch 4/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4634
# Epoch 5/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3671
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2910
# Epoch 7/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2308
# Epoch 8/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1832
# Epoch 9/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1456
# Epoch 10/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1158
# Epoch 11/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0923
# Epoch 12/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0737
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[0.99727637]], dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([0.0061914], dtype=float32)>]

# %%
# wx + b

print(model.weights[0].numpy()* x_train[0] +model.weights[1].numpy())
print(model.weights[0].numpy()* x_train[1] +model.weights[1].numpy())
print(model.weights[0].numpy()* 99 +model.weights[1].numpy())
# Out:
# [[0.9992494]]
# [[1.9998395]]
# [[99.05709]]

# %% [markdown]
# ## (2) 예제2

# %%
x= [1,2,3,4,5,6]
y= [3,4,5,6,7,8]

model= tf.keras.models.Sequential() # 박스 생성

model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear')) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=0.01)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 1)                 0
#
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0070
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2200
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3903
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0036
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8220
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7353
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6927
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6703
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6574
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6490
# Epoch 11/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6425
# Epoch 12/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6370
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.0114231]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([1.9510957], dtype=float32)>]

# %%
model.predict([4])
# Out:
# 1/1 [==============================] - 0s 126ms/step
# array([[5.996788]], dtype=float32)

# %%
import matplotlib.pyplot as plt

result.history.keys()
plt.plot(result.history['loss'])

# %% [markdown]
# ## (3) 예제3
# - 8시간 일했을 때 매출액은?

# %%
#### 매출액 예측
x= [1,2,3,4,5,6,7]
y= [25000, 55000, 75000, 110000, 128000, 155000, 180000]

# %%
model= tf.keras.models.Sequential() # 박스 생성

# model.add(Flatten(input_shape=(1,))) # 입력층. 1차원으로 풀어서 레이어 넣어주기

model.add(Dense(1, activation='linear', input_shape=(1,))) # 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=0.01)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 13456406528.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4594329600.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1573459328.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 543708736.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 192679904.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 73010536.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 32205650.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 18283804.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 13525770.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 11891610.0000
# Epoch 11/1000
# ...

# %%
model.weights
# Out:
# [<tf.Variable 'dense_4/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[25627.406]], dtype=float32)>,
#  <tf.Variable 'dense_4/bias:0' shape=(1,) dtype=float32, numpy=array([1505.0852], dtype=float32)>]

# %%
model.predict([8])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[206524.33]], dtype=float32)

# %% [markdown]
# ## (4) 예제4

# %%
x= [[73, 80, 75], [93, 88, 93], [89, 91, 90], [96, 98, 100], [73, 66, 70]]
y= [[152], [185], [180], [196], [142]]

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(3,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-5)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.0114231]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([1.9510957], dtype=float32)>]

# %%
print(model.predict([[73, 80, 75]])) # 148
print(model.predict([[93, 88, 93]])) # 186
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[148.11285]]
# 1/1 [==============================] - 0s 27ms/step
# [[186.75394]]

# %%
plt.plot(result.history['loss'])

# %% [markdown]
# ## (5) 예제5
# - 체중과 나이에 따른 혈당 예측
# - 체중이 100이고 나이가 40일때 혈당은?

# %%
import numpy as np

data= np.genfromtxt('data/x09.txt', skip_header=36)
data
# Out:
# array([[  1.,   1.,  84.,  46., 354.],
#        [  2.,   1.,  73.,  20., 190.],
#        [  3.,   1.,  65.,  52., 405.],
#        [  4.,   1.,  70.,  30., 263.],
#        [  5.,   1.,  76.,  57., 451.],
#        [  6.,   1.,  69.,  25., 302.],
#        [  7.,   1.,  63.,  28., 288.],
#        [  8.,   1.,  72.,  36., 385.],
#        [  9.,   1.,  79.,  57., 402.],
#        [ 10.,   1.,  75.,  44., 365.],
#        [ 11.,   1.,  27.,  24., 209.],
#        [ 12.,   1.,  89.,  31., 290.],
#        [ 13.,   1.,  65.,  52., 346.],
#        [ 14.,   1.,  57.,  23., 254.],
#        [ 15.,   1.,  59.,  60., 395.],
#        [ 16.,   1.,  69.,  48., 434.],
#        [ 17.,   1.,  60.,  34., 220.],
#        [ 18.,   1.,  79.,  51., 374.],
#        [ 19.,   1.,  75.,  50., 308.],
#        [ 20.,   1.,  82.,  34., 220.],
#        [ 21.,   1.,  59.,  46., 311.],
#        [ 22.,   1.,  67.,  23., 181.],
#        [ 23.,   1.,  85.,  37., 274.],
#        [ 24.,   1.,  55.,  40., 303.],
# ...

# %%
x= [data[i][1:4].tolist() for i in range(len(data))]
y= [i[4].tolist() for i in data]

# %%
x= data[:, 1:4]
y= data[:, 4]

# %%
x= np.array(data[:, 1:4], dtype=np.float32)
y= np.array(data[:, 4], dtype=np.float32)

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(3,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-5)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 158ms/step - loss: 76999.1328
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 59225.6836
# Epoch 3/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 45729.9648
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 35482.0742
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 27700.0645
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 21790.2422
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 17301.8770
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 13892.7314
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 11302.9785
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9335.3467
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7840.0664
# Epoch 12/1000
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_15/kernel:0' shape=(3, 1) dtype=float32, numpy=
#  array([[-0.76722646],
#         [ 1.4772904 ],
#         [ 5.3111925 ]], dtype=float32)>,
#  <tf.Variable 'dense_15/bias:0' shape=(1,) dtype=float32, numpy=array([0.08178992], dtype=float32)>]

# %%
print(model.predict([[1, 100, 40]])) # 362
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[359.49127]]

# %%
plt.plot(result.history['loss'])

# %% [markdown]
# ## (6) 예제6

# %%
loaded_data= np.loadtxt('data/sps.csv', delimiter=',', dtype=np.float32)
loaded_data
# Out:
# array([[  1.,   1.,   1.,   2.,   1.],
#        [ 14.,   2.,  -3.,   9.,   0.],
#        [  5.,   4.,   1.,   0.,  -2.],
#        [ -4.,   3.,   2.,   1.,   6.],
#        [  3.,   5.,   1.,   8.,   9.],
#        [  3.,  -1.,   5.,   8.,  -1.],
#        [  2.,   2.,   3.,   7.,   4.],
#        [  4.,   4.,   5.,   6.,   1.],
#        [  0.,   4.,   4.,   4.,   4.],
#        [ -2.,   1.,   1.,   3.,   5.],
#        [  1.,   7.,  -2.,   1.,   9.],
#        [  0.,   9.,   0.,   0.,   9.],
#        [  0.,   2.,   1.,   1.,   2.],
#        [  0.,   3.,   3.,   3.,   3.],
#        [-11.,   1.,   4.,  -7.,   1.],
#        [ -8.,   4.,   1.,  -9.,   2.],
#        [  5.,   2.,  -2.,   2.,   1.],
#        [  0.,   3.,   3.,   2.,   2.],
#        [ -6.,   1.,   6.,   1.,   2.],
#        [  1.,   4.,   5.,   4.,   2.],
#        [ -8.,   3.,   3.,  -7.,   1.],
#        [ 16.,   8.,  -7.,   8.,   7.],
#        [  0.,   1.,   2.,  -3.,  -4.],
#        [  0.,   0.,   0.,   0.,   0.],
# ...

# %%
x= loaded_data[:, 1:]
y= loaded_data[:, 0]

# %%
model= tf.keras.models.Sequential() # 박스 생성

model.add(Dense(1, activation='linear', input_shape=(4,))) # input 3개, 출력층. wx+ b -> 활성함수(분류에서만)

model.compile(loss='mse', optimizer=SGD(learning_rate=1e-2)) # 오차계산(mse), 오차 줄이기:SGD방식 으로 해결
# 학습률이 너무 크면 제대로 학습 안됨
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 1)                 5
#
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 40.3417
# Epoch 2/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 11.0809
# Epoch 3/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 5.3741
# Epoch 4/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7515
# Epoch 5/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3534
# Epoch 6/1000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6923
# Epoch 7/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3735
# Epoch 8/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1991
# Epoch 9/1000
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1002
# Epoch 10/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0519
# Epoch 11/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 12/1000
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_17/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[ 1.       ],
#         [-1.0000001],
#         [ 1.       ],
#         [-1.0000001]], dtype=float32)>,
#  <tf.Variable 'dense_17/bias:0' shape=(1,) dtype=float32, numpy=array([3.5518897e-07], dtype=float32)>]

# %%
plt.plot(result.history['loss'])

# %%
print(model.predict([[45, 33, 25, 68]])) # 362
# Out:
# 1/1 [==============================] - 0s 43ms/step
# [[-31.000011]]

# %% [markdown]
# ## 3

# %%
## (4) 고객 이탈율 예측

df= pd.read_csv('data/Customer_Churn_Modelling.csv')
df.head()

df.info()

### 1) Data Definition

X= df.drop(labels=['RowNumber','CustomerId','Surname','Exited'], axis=1)
y= df['Exited']

### 2) Preprocessing
# - 레이블 인코딩: 카테고리별로 숫자 부여
# - 원핫 인코딩: 카테고리를 컬럼으로

X

#### 레이블 인코딩 
from sklearn.preprocessing import LabelEncoder

label1= LabelEncoder()
X['Gender']= label1.fit_transform(X['Gender'])

label2= LabelEncoder()
X['Geography']= label1.fit_transform(X['Geography'])

X

#### 원핫 인코딩
X_num= X[X.columns[[0,3,4,5,9]]]
X_num

X_cat= X[X.columns[[1,2,6,7,8]]]
X_cat

X_cat= pd.get_dummies(X_cat, drop_first=True)
X_cat

#### 정규화
std = StandardScaler()
std.fit(X_num)
X_scaled = std.transform(X_num)

#### 정규화

X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=0, stratify= y, test_size=.2)
scaler= StandardScaler()
X_train= scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

X_final = pd.concat([pd.DataFrame(X_scaled), X_cat], axis=1, ignore_index=True)
X_final

### 3) 모델 구축
# - hidden layer: 6개
# - 각 입출력 갯수: 128개
# - 가중치 초기화: he_normal
# - Activation Function: relu
# - Optimizer: Adam(0.001)
# - ephocs: 100
# - validation: yes

# model= Sequential()

# model.add(Flatten(input_shape=(13,)))
# model.add(Dense(128,activation='relu',kernel_initializer='he_normal'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(1,activation='sigmoid'))

# model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# result = model.fit(X_final, y ,validation_split=0.2, epochs=100)

# loss: 0.0356 - accuracy: 0.9877 - val_loss: 1.4036 - val_accuracy: 0.8290

model= Sequential()
model.add(Dense(128, input_shape=(X.shape[1],), activation='relu', kernel_initializer='he_normal'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()

result= model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# Model: "sequential_1"
# ...

# %% [markdown]
# ## 4

# %%
x= [[73, 80, 75], [93, 88, 93], [89, 91, 90], [96, 98, 100], [73, 66, 70]]
y= [[152], [185], [180], [196], [142]]

# %%
x = np.array([ [1, 2, 0], [5, 4, 3], [1, 2, -1], [3, 1, 0], [2, 4, 2],
[4, 1, 2], [-1, 3, 2], [4, 3, 3], [0, 2, 6], [2, 2, 1],
[1, -2, -2], [0, 1, 3], [1, 1, 3], [0, 1, 4], [2, 3, 3] ])

y = np.array([-4, 4, -6, 3, -4,
9, -7, 5, 6, 0,
4, 3, 5, 5, 1])

# %%
model= tf.keras.models.Sequential()
model.add(Dense(1, activation='linear', input_shape=(3,))) 
model.compile(loss='mse', optimizer=SGD(learning_rate=1e-5))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
result= model.fit(x, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 162ms/step - loss: 36.3457
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.3338
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 36.3219
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.3100
# Epoch 5/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.2981
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.2862
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 36.2743
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 36.2624
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 36.2506
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.2387
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 36.2268
# Epoch 12/1000
# ...

# %%
model.weights # 0.99, 0.00
# Out:
# [<tf.Variable 'dense_14/kernel:0' shape=(3, 1) dtype=float32, numpy=
#  array([[ 0.19120526],
#         [-0.52413446],
#         [ 0.34538162]], dtype=float32)>,
#  <tf.Variable 'dense_14/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
print(model.predict([[73, 80, 75]])) # 148
print(model.predict([[93, 88, 93]])) # 186
# Out:
# 1/1 [==============================] - 0s 112ms/step
# [[-2.069149]]
# 1/1 [==============================] - 0s 28ms/step
# [[3.7787476]]

# %% [markdown]
# ## 5

# %%
import tensorflow as tf
import numpy as np


input_shape = (32, 32, 1)


model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


X_train = np.random.randn(100, 32, 32, 1)  # 100개의 입력 이미지
y_train = np.random.randint(0, 4, size=(100,))  # 100개의 레이블 (0~3 사이의 값)


model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 3ms/step - loss: 1.5439 - accuracy: 0.3000
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0146 - accuracy: 0.7500
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7868 - accuracy: 0.9000
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6197 - accuracy: 0.9800
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4902 - accuracy: 1.0000
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3784 - accuracy: 1.0000
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2853 - accuracy: 1.0000
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2092 - accuracy: 1.0000
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
model.predict([0.2,0.1,0.6,0.1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_56984\3165667306.py in <module>
# ----> 1 model.predict([0.2,0.1,0.6,0.1])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
# ...
