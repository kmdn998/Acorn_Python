# %%
#고객관리 프로그램을 파일처리, 함수화, 클래스로.
# 이름, 전화번호, 주소를 저장
# 친구관리 클래스로
# 파일로 저장
# DB로 저장

# %%
class Manage:
    
    def __init__(self):
        self.nlist=[]
#         print('1. 친구 리스트 출력 = show()')
#         print('2. 친구 추가 = append(name)')
#         print('3. 친구 삭제 = remove(name)')
#         print('4. 이름 변경 = change(oldname, newname)')
#         print('9. 종료 = finish()')

    def show(self):
#         print(self.nlist)
        file= open('data/고객관리.txt','r',encoding='utf8')
        for i in file.readlines():
            print(i)
        file.close()
        
    def append(self, name,phone,add):
#         self.nlist.append(name)
#         self.show()
        file= open('data/고객관리.txt','a',encoding='utf8')
        file.write(f'{name},{phone},{add}\n')
        file.close()
        
    def delete(self, name):
#         self.nlist.remove(name)
#         self.show()
        file= open('data/고객관리.txt','r',encoding='utf8')
        lines=file.readlines()
        new=[]
        for i in range(len(lines)):
            f=lines[i].find(name)
            if f == -1:
                new.append(lines[i])
            newfile= open('data/고객관리.txt','a',encoding='utf8')
            newfile.write(f'new{lines[i]}\n')
#         newfile= open('data/고객관리.txt','w',encoding='utf8')
#         newfile.write({lines[i]})
        self.show()
        # 기존 파일을 한 문장씩 돌리면서 같은 이름이 있는지 확인
        # 같은 이름이 없으면 리스트에 저장 후
        # 기존 파일에 덮어쓰기
    def change(self, oldname, newname):
        self.nlist[self.nlist.index(oldname)]= newname
        self.show()
    
    def finish(self):
        self.show()
        
NewJeans= Manage()

# %%
NewJeans.append('이름',ph,50)

NewJeans.show()
ph +=1
# Out:
# 이름,5,50
#
# 이름,6,50
#
# 이름,7,50
#
# 이름,8,50
#
# 이름,9,50
#
# 이름,10,50
#
# 이름,11,50
#
# 이름,12,50
#
# 이름,13,50
#
# 이름,14,50
#
# 이름,15,50
#
# 이름,5,50
#
#
#
# 이름,6,50
#
#
#
# 이름,7,50
#
#
#
# 이름,8,50
#
#
#
# 이름,9,50
#
#
#
# 이름,10,50
#
#
#
# 이름,11,50
#
#
#
# 이름,12,50
#
#
#
# 이름,13,50
#
#
#
# 이름,14,50
#
#
#
# 이름,15,50
#
#
#
# 이름,16,50
#
# new이름,5,50
#
#
#
# new이름,6,50
#
#
#
# new이름,7,50
#
#
#
# new이름,8,50
#
#
#
# new이름,9,50
#
#
#
# new이름,10,50
#
#
#
# new이름,11,50
#
#
#
# new이름,12,50
#
#
#
# new이름,13,50
#
#
#
# new이름,14,50
#
#
#
# new이름,15,50
#
#
#
# new이름,5,50
#
#
#
# new
#
#
#
# new이름,6,50
#
#
#
# new
#
#
#
# new이름,7,50
#
#
#
# new
#
#
#
# new이름,8,50
#
#
#
# new
#
#
#
# new이름,9,50
#
#
#
# new
#
#
#
# new이름,10,50
#
#
#
# new
#
#
#
# new이름,11,50
#
#
#
# new
#
#
#
# new이름,12,50
#
#
#
# new
#
#
#
# new이름,13,50
#
#
#
# new
#
#
#
# new이름,14,50
#
#
#
# new
#
#
#
# new이름,15,50
#
#
#
# new
#
#
#
# new이름,16,50
#
#
#
# 이름,1,50

# %%
NewJeans.delete('1')
# Out:
# 이름,5,50
#
# 이름,6,50
#
# 이름,7,50
#
# 이름,8,50
#
# 이름,9,50
#
# 이름,10,50
#
# 이름,11,50
#
# 이름,12,50
#
# 이름,13,50
#
# 이름,14,50
#
# 이름,15,50
#
# 이름,5,50
#
#
#
# 이름,6,50
#
#
#
# 이름,7,50
#
#
#
# 이름,8,50
#
#
#
# 이름,9,50
#
#
#
# 이름,10,50
#
#
#
# 이름,11,50
#
#
#
# 이름,12,50
#
#
#
# 이름,13,50
#
#
#
# 이름,14,50
#
#
#
# 이름,15,50
#
#
#
# 이름,16,50
#
# new이름,5,50
#
#
#
# new이름,6,50
#
#
#
# new이름,7,50
#
#
#
# new이름,8,50
#
#
#
# new이름,9,50
#
#
#
# new이름,10,50
#
#
#
# new이름,11,50
#
#
#
# new이름,12,50
#
#
#
# new이름,13,50
#
#
#
# new이름,14,50
#
#
#
# new이름,15,50
#
#
#
# new이름,5,50
#
#
#
# new
#
#
#
# new이름,6,50
#
#
#
# new
#
#
#
# new이름,7,50
#
#
#
# new
#
#
#
# new이름,8,50
#
#
#
# new
#
#
#
# new이름,9,50
#
#
#
# new
#
#
#
# new이름,10,50
#
#
#
# new
#
#
#
# new이름,11,50
#
#
#
# new
#
#
#
# new이름,12,50
#
#
#
# new
#
#
#
# new이름,13,50
#
#
#
# new
#
#
#
# new이름,14,50
#
#
#
# new
#
#
#
# new이름,15,50
#
#
#
# new

# %%
#4. 숫자맞추기 1~100. 힌트 세분화. 총 시도 횟수
import random
ans= random.randint(1,10)
total=0

while True:
    num= int(input('숫자:'))
    if ans> num: print('higher')
    elif ans<num: print('lower')
    elif ans==num: 
        print('정답입니다')
        break
    total+=1
    print()
    
print(f'총 시도 횟수:{total}')  
    
#2. 가위 바위 보 게임 x나 q 종료 n승 n패
import random
win, lose, same=0,0,0
while True:
    me= input('"가위", "바위", "보" 중에서 하나를 입력하세요: ')
    if me in ['x','q']: 
        print(f'{same}무 {win}승 {lose}패')
        break
        
    rand= random.randint(0,2)
    if rand==0: com= '가위'
    elif rand==1: com= '바위'
    else: com= '보'
    
    if me not in ['가위', '바위', '보']: print('잘못 입력하였습니다')
    else:
        if me== '가위':
            if com=='가위': 
                result= 'same'
#                 same +=1
            elif com=='바위': 
                result= 'lose'
#                 lose += 1
            elif com=='보': 
                result= 'win'
#                 win +=1
        elif me=='바위':
            if com=='가위': 
                result= 'win'
                win +=1
            elif com=='바위': 
                result= 'same'
                same +=1
            elif com=='보': 
                result= 'lose'
                lose += 1
        elif me=='보':
            if com=='가위': 
                result= 'lose'
                lose += 1
            elif com=='바위': 
                result= 'win'
                win +=1
            elif com=='보': 
                result= 'same'  
                same +=1
    
    
        print('컴퓨터:',com)
        print('나:',me)
        print('결과:',result,'\n')
        result=0

# %%
import random

def playgame(me):
    win, lose, same=0,0,0
#         me= input('"가위", "바위", "보" 중에서 하나를 입력하세요: ')
    if me in ['x','q']: 
        print(f'{same}무 {win}승 {lose}패')

    rand= random.randint(0,2)
    if rand==0: com= '가위'
    elif rand==1: com= '바위'
    else: com= '보'

    if me not in ['가위', '바위', '보']: 
        print('잘못 입력하였습니다')
   

    elif me == com:
        result= 'same' #얘 왜 안됨..?
        same +=1
    else:
        if me== '가위':
            if com=='바위': 
                result= 'lose'
                lose += 1
            elif com=='보': 
                result= 'win'
                win +=1
        elif me=='바위':
            if com=='가위': 
                result= 'win'
                win +=1
            elif com=='보': 
                result= 'lose'
                lose += 1
        elif me=='보':
            if com=='가위': 
                result= 'lose'
                lose += 1
            elif com=='바위': 
                result= 'win'
                win +=1
    print('컴퓨터:',com)
    print('나:',me)
    print('결과:',result,'\n')

# %%
playgame('가위')
# Out:
# 컴퓨터: 가위
# 나: 가위
# 결과: same

# %%
        while True:
            pick= input('게임을 시작하시려면 "가위바위보" 또는 "숫자맞추기"를 입력하세요: ')
            if pick=="가위바위보": RCP.playRCP(self)
            elif pick=="숫자맞추기": RandomNum.playRNum(self)
            else: break
# Out:
# 게임을 시작하시려면 "가위바위보" 또는 "숫자맞추기"를 입력하세요: ㅇ

# %%
import random

class RCP:
    def playRCP(self):
        win, lose, same=0,0,0
        while True:
            me= input('"가위", "바위", "보" 중에서 하나를 입력하세요: ')
            if me in ['x','q']: 
                print(f'{same}무 {win}승 {lose}패')
                break
                
            rand= random.randint(0,2)
            if rand==0: com= '가위'
            elif rand==1: com= '바위'
            else: com= '보'
            
            if me not in ['가위', '바위', '보']: 
                print('잘못 입력하였습니다')
                continue
                
            elif me == com:
                result= 'same'
                same +=1
            else:
                if me== '가위':
                    if com=='바위': 
                        result= 'lose'
                        lose += 1
                    elif com=='보': 
                        result= 'win'
                        win +=1
                elif me=='바위':
                    if com=='가위': 
                        result= 'win'
                        win +=1
                    elif com=='보': 
                        result= 'lose'
                        lose += 1
                elif me=='보':
                    if com=='가위': 
                        result= 'lose'
                        lose += 1
                    elif com=='바위': 
                        result= 'win'
                        win +=1
            print('컴퓨터:',com)
            print('나:',me)
            print('결과:',result,'\n')

class RandomNum:
    #4. 숫자맞추기 1~100. 힌트 세분화. 총 시도 횟수
    def playRNum(self):
        ans= random.randint(1,100)
        total=0

        while True:
            num= int(input('숫자:'))
            if ans> num+20: print('MUCH higher')
            elif ans > num: print('higher')
            elif ans < num-20: print('MUCH lower')
            elif ans < num: print('lower')
            elif ans==num: 
                print('정답입니다')
                break
            total+=1
            print()
            if total >5: print(ans)
        
        print(f'총 시도 횟수:{total}')

class Games(RCP, RandomNum):
    def __init__(self):
        while True:
            pick= input('게임을 시작하시려면 "1" 또는 "2"를 입력하세요: ')
            if pick=="1": RCP.playRCP(self)
            elif pick=="2": RandomNum.playRNum(self)
            else: break
            

# t1=RCP()
# t1.playgame()
# t2=RandomNum()
# t2.playRNum()

t3=Games()
# Out:
# 게임을 시작하시려면 "1" 또는 "2"를 입력하세요: ff
