# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name= fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()
plt.rc('font',family=font_name)

import matplotlib as mlp
mlp.rcParams['axes.unicode_minus']=False

from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Selenium
# 원격으로 프로그램 조종 가능
# - 자바스크립트가 동적으로 만든 데이터를 크롤링하기 위해 만들어진 모듈
#     - 사이트의 다양한 HTML요소에 클릭, 키보드 입력 등 이벤트를 주기 위해 이 기능을 잘 활용하면
#     - 평소에 반복적으로 하고있는 웹 상의 업무를 자동화할 수 있다.
# - 용도
#     - 자동 로그인
#     - 메일 보내기 자동화
#     - sns 좋아요 누르기
#     - sns 댓글 작성
# - 준비물
#     - pip install selenium
#     - 원격 프로그램
#         - Chrome Driver # chrome버전과 맞추기
#         - Phantom JS
#         - ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ## 1. 간단한 사용법
# ### (1) 원격 웹브라우저 켜고 끄기

# %%
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
driver.get('https://naver.com')
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_12996\2460872367.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
driver.close()

# %% [markdown]
# ### (2) 원격 웹 브라우저 조종하기

# %%
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_12996\2717239994.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
driver.get('https://naver.com')
driver.get('https://daum.net')

# %%
# 뒤로가기
driver.back()

# %%
# 앞으로 가기
driver.forward()

# %%
# 새로고침
driver.refresh()
# 스크린샷
driver.save_screenshot('data/daum1.png')
# Out:
# True

# %% [markdown]
# ### (3) 원격 웹 브라우저에 키보드값 전달

# %%
# By.ID id로 검색
element= driver.find_element(By.ID, 'q')
element.clear()
element.send_keys('노트북') # element에 '노트북' 키보드 입력

# %%
element.send_keys(Keys.ENTER) # 엔터키

# %%
driver.close()

# %% [markdown]
# ## 2. 다음 로그인 자동화

# %%
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
url= 'https://daum.net'
driver.get(url)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_12996\2651909262.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
# 로그인 버튼 클릭
element= driver.find_element(By.CLASS_NAME, 'link_login')
element.click()

# %%
driver.find_element(By.ID, 'loginKey--1').send_keys('ehdusrla812@naver.com')
driver.find_element(By.ID, 'password--2').send_keys('2075714a')
driver.find_element(By.CLASS_NAME, 'submit').click()

# %% [markdown]
# ## 3. 포털 사이트 뉴스 수집하기

# %%
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
url= 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105'
driver.get(url)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\4126877030.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
ultag= driver.find_element(By.ID, '_rankingList0')
litags= ultag.find_elements(By.TAG_NAME, 'li') # li태그들 불러오기
for li in litags: 
    atag= li.find_element(By.CLASS_NAME, 'list_tit')
    print(atag.text)
# Out:
# 속도·신호 카메라 지났다고 '안심' 금물…뒷번호판 촬영
# “안 쓰는 삼성폰, 서랍에 넣어뒀는데” 4년만에 46만원 …
# "1000만원 벌면 절반 넘게 떼가요"…9년차 미용사의 고 …
# 4살 아이 우물에 빠뜨린 7살‥"TV 장면 따라 했어요"
# 루브르 박물관 문 닫았다 “64살까지 일해야 연금 주겠다니 …

# %% [markdown]
# ## 4. 포털 사이트 검색 결과 수집하기

# %%
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
url= 'https://naver.com'
driver.get(url)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\4196730552.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
element= driver.find_element(By.ID, 'query')
element.clear()
element.send_keys('파이썬')
element.send_keys(Keys.ENTER)

# %%
tabs= driver.find_elements(By.CLASS_NAME, 'tab') 
# element 아니고 driver로 접근 
for tab in tabs:
    if(tab.text =='VIEW'):
        tab.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6092\1200410710.py in <module>
#       2 # element 아니고 driver로 접근
#       3 for tab in tabs:
# ----> 4     if(tab.text =='VIEW'):
#       5         tab.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      88     def text(self) -> str:
#      89         """The text of the element."""
# ---> 90         return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#      91
#      92     def click(self) -> None:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     402             params = {}
#     403         params["id"] = self._id
# --> 404         return self._parent.execute(command, params)
#     405
#     406     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=111.0.5563.147)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0052DCE3]
# 	(No symbol) [0x004C39D1]
# 	(No symbol) [0x003D4DA8]
# 	(No symbol) [0x003D76FB]
# 	(No symbol) [0x003D75D0]
# 	(No symbol) [0x003D7850]
# 	(No symbol) [0x003FC330]
# 	(No symbol) [0x0041AECC]
# 	(No symbol) [0x003F8726]
# 	(No symbol) [0x0041B224]
# 	(No symbol) [0x0042D57C]
# 	(No symbol) [0x0041ACC6]
# 	(No symbol) [0x003F6F68]
# 	(No symbol) [0x003F80CD]
# 	GetHandleVerifier [0x007A3832+2506274]
# 	GetHandleVerifier [0x007D9794+2727300]
# 	GetHandleVerifier [0x007DE36C+2746716]
# 	GetHandleVerifier [0x005D6690+617600]
# 	(No symbol) [0x004CC712]
# 	(No symbol) [0x004D1FF8]
# 	(No symbol) [0x004D20DB]
# 	(No symbol) [0x004DC63B]
# 	BaseThreadInitThunk [0x74EC00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F07BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F07B8E+238]

# %%
elements= driver.find_elements(By.CLASS_NAME, 'total_tit')
for ele in elements:
    print(ele.text)
# Out:
# 고려대 박사 교수님의 파이썬 명강의로 완벽 마스터!
# 프로그램 언어 C언어,자바,파이썬 어떻게 공부하지?
# 웹크롤링 파이썬 몰라도 챗GPT 사용법만 알아도 된다.
# 파이썬학원 : Python기초부터 IT취업까지
# 파이썬 언어의 뜻과 장점, 기본 개발 환경 구축 방법
# [대전환 코딩 개발자 도전] 05. print('hello, 파이썬 world!')
# 파이썬학원 고효율의 교육과정
# 파이썬 공부는 IT전문교육기관 아이티동스쿨에서!
# 비전공자도 SQL,파이썬,빅데이터 전문가로 거듭나기
# 프로그래밍, 어렵지 않아요!! 파이썬함수부터 시작해 볼까요?
# 문과 출신이 파이썬 독학해도 개발자 취업 할 수 없는 이유
# [용어사전] 파이썬 공부를 시작하기 전에 미리 알아두면 좋은 파이썬 용어 정리③ (자~하)
# 개발자 협업 위한 Git, Github "파이썬 코드로 배우는 Git&Github" 로 배워보자
# 부산파이썬학원, 제대로 알고 하십니까?
# 프론트엔드 파이썬 알아야하나요?
# 빅분기 실기 파이썬 설치
# 파이썬 기초 : 이해도의 핵심은 과연 수학인가?
# 파이썬으로 앱개발 배우고 싶은데요
# 클린코드, 이제는 파이썬이다 스터디 #8
# #파이썬 #세 번째 과제
# m2 파이썬으로 인공지능 코딩을 배우려는데요ㅠㅠ
# 파이썬입문 코딩처음이라면 프로그램설치부터 IT교육학원
# nas에서 파이썬 돌리려고 하는데요
# [Python + Jupyter Notebook] 파이썬 + 주피터 노트북 설치하기
# R에서 파이썬으로 변경 관련
# 파이썬 에디터 추천 부탁드립니다!
# 파이썬 프로그래밍 개발 언어의 활용 방법과 장점 단점
# 파이썬(Python) - 바이트 배열 간단하게 비교하기
# 파이썬 윈도우11에서의 블루투스 기기 연동 불가
# 파이썬이 대세
# 실무 개발자를 위한 최적화 기법 : 클린 코드의 기술 (파이썬 예제 포함)
# 파이썬학원 실무과정이 필요한 이유
# 점프투파이썬 - 문과생도 파이썬입문 쌉가능!
# 파이썬배우기 코딩기초부터 단계별로 IT교육학원

# %%
# 드라이버에서 바로 원하는 곳으로 접근하기
driver.find_element(By.XPATH, '//*[@id="lnb"]/div[1]/div/ul/li[4]/a').click()

# %%
elements= driver.find_elements(By.CLASS_NAME, 'total_tit')
for ele in elements:
    print(ele.text)
    print(ele.get_attribute('href'))
# Out:
# 고려대 박사 교수님의 파이썬 명강의로 완벽 마스터!
# https://adcr.naver.com/adcr?x=ENfIMEaaqNqWiedw6EwXmv///w==...
# 프로그램 언어 C언어,자바,파이썬 어떻게 공부하지?
# https://adcr.naver.com/adcr?x=k19ac9jHFwf44MmIwQtxUP///w==...
# 웹크롤링 파이썬 몰라도 챗GPT 사용법만 알아도 된다.
# https://blog.naver.com/ocmarketing/223040044418
# 파이썬학원 : Python기초부터 IT취업까지
# https://blog.naver.com/ridesafe/223054476246
# 파이썬 언어의 뜻과 장점, 기본 개발 환경 구축 방법
# https://blog.naver.com/hj_bw/223027606762
# [대전환 코딩 개발자 도전] 05. print('hello, 파이썬 world!')
# https://blog.naver.com/hanainde/223052733822
# 파이썬학원 고효율의 교육과정
# https://blog.naver.com/da870108/223058250605
# 파이썬 공부는 IT전문교육기관 아이티동스쿨에서!
# https://adcr.naver.com/adcr?x=GwWKyZDGHk9PeqH6OP7gS////w==...
# 비전공자도 SQL,파이썬,빅데이터 전문가로 거듭나기
# https://adcr.naver.com/adcr?x=6pWMyEaDhV6Lb51YXuWcTv///w==...
# 프로그래밍, 어렵지 않아요!! 파이썬함수부터 시작해 볼까요?
# https://blog.naver.com/ithopenanum/223033635830
# 문과 출신이 파이썬 독학해도 개발자 취업 할 수 없는 이유
# https://post.naver.com/viewer/postView.naver?volumeNo=31910132&memberNo=47129033&vType=VERTICAL
# [용어사전] 파이썬 공부를 시작하기 전에 미리 알아두면 좋은 파이썬 용어 정리③ (자~하)
# https://post.naver.com/viewer/postView.naver?volumeNo=22111709&memberNo=25379965&vType=VERTICAL
# 개발자 협업 위한 Git, Github "파이썬 코드로 배우는 Git&Github" 로 배워보자
# https://hkebi.tistory.com/2463
# 부산파이썬학원, 제대로 알고 하십니까?
# https://blog.naver.com/gnuoes66/223054730965
# 프론트엔드 파이썬 알아야하나요?
# https://cafe.naver.com/hacosa/318183?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImhhY29zYSIsImFydGljbGVJZCI6MzE4MTgzLCJpc3N1ZWRBdCI6MTY4MDA1Mjc1MTExMX0.ykI7Xpg0C1mxQb2x2CPVz1o5EmEpTt_182rhDt0MavI
# 빅분기 실기 파이썬 설치
# https://cafe.naver.com/sqlpd/48500?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InNxbHBkIiwiYXJ0aWNsZUlkIjo0ODUwMCwiaXNzdWVkQXQiOjE2ODAwNTI3NTExMTF9.rL7ZTLom3Vaj17uBXvTTj7njrBo80K_uEzp8QaxFXOc
# 파이썬 기초 : 이해도의 핵심은 과연 수학인가?
# https://blog.naver.com/urmyver/222988103318
# 파이썬으로 앱개발 배우고 싶은데요
# https://cafe.naver.com/appleiphone/7839325?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImFwcGxlaXBob25lIiwiYXJ0aWNsZUlkIjo3ODM5MzI1LCJpc3N1ZWRBdCI6MTY4MDA1Mjc1MTExMn0.RRUNtA2t146qhQUPNm_PijG0a7Sd3ahjCEFRPf-V3o4
# 클린코드, 이제는 파이썬이다 스터디 #8
# https://blog.naver.com/clarkesquare/223058394381
# #파이썬 #세 번째 과제
# https://blog.naver.com/myway855/223050085170
# m2 파이썬으로 인공지능 코딩을 배우려는데요ㅠㅠ
# https://cafe.naver.com/inmacbook/2597364?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlubWFjYm9vayIsImFydGljbGVJZCI6MjU5NzM2NCwiaXNzdWVkQXQiOjE2ODAwNTI3NTExMTN9.yLCLm7p7UchOSfwVn67_OxIBvdLeUE2IIGO4qpyP6Co
# 파이썬입문 코딩처음이라면 프로그램설치부터 IT교육학원
# https://blog.naver.com/vg2306/223054365142
# nas에서 파이썬 돌리려고 하는데요
# https://cafe.naver.com/synologynas/190557?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InN5bm9sb2d5bmFzIiwiYXJ0aWNsZUlkIjoxOTA1NTcsImlzc3VlZEF0IjoxNjgwMDUyNzUxMTE0fQ.QSY2lacretMafiVnz_DDImmq5KCCR5WGs54uSl4wdhc
# [Python + Jupyter Notebook] 파이썬 + 주피터 노트북 설치하기
# https://blog.naver.com/songsite123/223049049553
# R에서 파이썬으로 변경 관련
# https://cafe.naver.com/sqlpd/48771?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InNxbHBkIiwiYXJ0aWNsZUlkIjo0ODc3MSwiaXNzdWVkQXQiOjE2ODAwNTI3NTExMTV9._b4Sb8uD0KTDwYrAyEUB2YCnNnX8pHrDJ-mrXbfm-vo
# 파이썬 에디터 추천 부탁드립니다!
# https://cafe.naver.com/fx8300/984857?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImZ4ODMwMCIsImFydGljbGVJZCI6OTg0ODU3LCJpc3N1ZWRBdCI6MTY4MDA1Mjc1MTExNn0.r0tWENAwNM5J3uvq7G_DsgUuvqNzlOZRKMVAx3wY9q8
# 파이썬 프로그래밍 개발 언어의 활용 방법과 장점 단점
# https://blog.naver.com/windangelic/223048973660
# 파이썬(Python) - 바이트 배열 간단하게 비교하기
# https://blog.naver.com/chandong83/223029299451
# 파이썬 윈도우11에서의 블루투스 기기 연동 불가
# https://cafe.naver.com/carroty/379957?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImNhcnJvdHkiLCJhcnRpY2xlSWQiOjM3OTk1NywiaXNzdWVkQXQiOjE2ODAwNTI3NTExMTd9.pXFARKnFc1eoExoaTQQOYrsrLi5A_fa5ucu_qYUvbWU
# 파이썬이 대세
# https://cafe.naver.com/isajime/5514993?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImlzYWppbWUiLCJhcnRpY2xlSWQiOjU1MTQ5OTMsImlzc3VlZEF0IjoxNjgwMDUyNzUxMTE3fQ.fZBJ5FBdhnx9Tgz5FMEccYgtXzzcZywKXh6HfJhm8LQ
# 실무 개발자를 위한 최적화 기법 : 클린 코드의 기술 (파이썬 예제 포함)
# https://blog.naver.com/pareko/223033498969
# 파이썬학원 실무과정이 필요한 이유
# https://blog.naver.com/rame83/223052608803
# 점프투파이썬 - 문과생도 파이썬입문 쌉가능!
# https://blog.naver.com/okok1326/222947193023
# 파이썬배우기 코딩기초부터 단계별로 IT교육학원
# https://blog.naver.com/dbals1152/223051409355

# %% [markdown]
# ## 5. 온라인 카페 검색 결과 가져오기
# - iframe 주의

# %%
url= 'https://cafe.naver.com/joonggonara'
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
driver.get(url)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\3291251852.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %%
import time
element= driver.find_element(By.ID, 'topLayerQueryInput')
element.send_keys('자전거')
element.send_keys(Keys.RETURN)

time.sleep(3)

# %%
iframe= driver.find_element(By.ID, 'cafe_main')
# 밖의 html에서 안의 html으로 바꾸기
driver.switch_to.frame(iframe)
# driver의 시작점이 iframe으로 바뀜

# %%
# <iframe>: html 안의 html.
articles= driver.find_elements(By.CLASS_NAME, 'article')
for arti in articles:
    print(arti.text)
    
time.sleep(3)
# Out:
# 휠라운동화220사이즈+bx모자 전부새제품2.5택무(사은품 운동화끈블랙)/나이키조던 스우시 헤리티지 아노락 acg nsw sb/아디다스 노스페이스/캠핑 골프 낚시 등산 아웃도어 자전거 헬스 조깅 여행
# 자전거MT
# 자전거(할리데이비스)
# 자전거
# 자전거MT
# 접이식자전거18인치
# 자전거16인치
# 자이언트 SCR2 자전거
# LED 충전식 자전거 라이트 전조등 후미등 프론트 테일 세트
# 첼로케인105 풀카본 로드자전거
# 19년 자이언트 TCR 어드밴스 SL 0 red s사이즈 정가 930만원 자전거 380만원에 팝니다
# 투리스모사토 차박 견인장치 자전거 캐리어포함
# 전기자전거 배터리 모토벨로 프로3 48V 20A 팝니다
# 지아이엘 스탠드 자전거 거치대 판매합니다 ( 택배불가 )
# 지아이엘 스탠드 자전거 거치대 판매합니다 ( 택배불가 )

# %%
articles= driver.find_elements(By.CLASS_NAME, 'article-board')
trs= articles[1].find_elements(By.XPATH, '//*[@id="main-area"]/div[5]/table/tbody/tr')
for tr in trs:
    title= tr.find_element(By.CLASS_NAME, 'article')
    print(title.text)
# Out:
# 자이언트 자전거 팝니다
# 트렉 trek fx2 자전거
# 트랙슈퍼칼리버9.8 xo1axs 무선전동 업글자전거 L사이즈 mtb 플샥
# 자동차에 붙일 만한 캠핑/자전거/서핑/낚시 방수 스티커 판매해요.(50장씩 약3천원)
# [앱상품]킥보드 자전거 led 라이트+거치대 새상품
# [앱상품]전동킥보드 자전거 전자제품 육각렌치 키트 새상품
# 최고급 핸드폰거치대 GUB 정품 자전거 핸드폰 거치대 폰거치대 싸이클 mtb 킥보드 전기자전거 스쿠터 장착가능 GUB G-85 SL 팔아요
# 폰에 붙이기 좋은 캠핑/자전거/서핑/낚시 방수 스티커 판매해요.(50장씩 약3천원)
# 산티니 여성 자전거복 긴팔 져지 S 사이즈 1회착용
# 자전거 전용 양말 팝니다 ! 자전거양말 5천원
# 패션 자전거 양말 GIRO 팔아요. 클릿 슈즈 위에 자전거양말 진짜 이뻐요 ! 자전거 패션의 완성품
# HJC R4 자전거 킥보드 헬멧
# 자전거 양말 싸게 팝니다 ! GIRO 지로 산악 로드 자전거 라이딩 바이크 패션 일상 아웃도어 스포츠 배드민턴 야구 농구 자전거양말
# 풀카본 로드 자전거 정리
# 트렉 fx2 하이브리드 자전거 팝니다.

# %% [markdown]
# ### (1) 페이지 네비게이션 처리

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

url= 'https://cafe.naver.com/joonggonara'
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

try:
    driver.get(url)
    
    # 검색어 입력
    element= driver.find_element(By.ID, 'topLayerQueryInput')
    element.send_keys('자전거')
    element.send_keys(Keys.RETURN)
    time.sleep(3)
    
    # iframe 접근
    iframe= driver.find_element(By.ID, 'cafe_main')
    driver.switch_to.frame(iframe)
    
    titles=[]
    for i in range(1,21):
        
        if i==11:
            page= driver.find_element(By.CLASS_NAME, 'pgR')
            page.click()  
        else:
            page= driver.find_element(By.LINK_TEXT, str(i))
            page.click()
            time.sleep(2)        
        
        articles= driver.find_elements(By.CLASS_NAME, 'article')
        for arti in articles:
            titles.append(arti.text)

    print(len(titles))

except Exception as e:
    print(e)

finally:
    driver.close() # 브라우저 하나 종료
    driver.quit() # 브라우저 전체 종료
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\3276669703.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')
# 툴레 598 자전거캐리어 블랙 2대
# 인테리어 알루미늄 컵홀더 자전거, 바이크, 스쿠터, 인더스트리얼 인테리어
# 오토바이 자전거 스피커 헬멧 스피커 미개봉 새제품 자전거 스쿠터
# 에어로타입)15년 메리다 리액토 400 로드자전거 xs사이즈
# 스카닉m180 팔아요 전기자전거 부산
# 상태A급 16년 캐논데일 슈퍼식스 에보 카본 로드자전거 56사이즈 팔아요.
# [앱상품]엘파마 벤토르 V4000 MTB 자전거 27.5인치
# [앱상품]스캇포일 로드자전거 에어로
# 자전거 거치대
# 정품 블리츠고글 자전거고글 스포츠고글 비전 비젼 판매합니다.
# 예거 아스펜5 27.5 mtb 자전거판매합니다
# 캐논데일 슈퍼식스에보 105구동계 카본 로드 자전거
# 예거 마리온 D8 전동 구동계 디스크 로드 자전거
# 나이키 헤리티지86 코듀로이모자+나이키 나침판고리 희귀제품 전부새제품4.7택무/나이키조던 스우시 헤리티지 아노락 acg nsw sb/스투시 슈프림 베이프 아디다스/캠핑 골프 낚시 등산 아웃도어 노스페이스 자전거
# 삼천리 트레이스 어린이 자전거 16인치

# %%
titles=[]

for i in range(1,21):
    if i==11:
        page= driver.find_element(By.CLASS_NAME, 'pgR')
        page.click()  
    else:
        page= driver.find_element(By.LINK_TEXT, str(i))
        page.click()
        time.sleep(2)
        
    articles= driver.find_elements(By.CLASS_NAME, 'article')
    for arti in articles:
        titles.append(arti.text)    

print(len(titles))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000024C6B0C8B50>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6092\4251510916.py in <module>
#       2
#       3 for i in range(1,21):
# ----> 4     articles= driver.find_elements(By.CLASS_NAME, 'article')
#       5     for arti in articles:
#       6         titles.append(arti.text)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#     859         # Return empty list if driver returns null
#     860         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 861         return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#     862
#     863     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     436                 params["sessionId"] = self.session_id
#     437
# --> 438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
#     440             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     288         data = utils.dump_json(params)
#     289         url = f"{self._url}{path}"
# --> 290         return self._request(command_info[0], url, body=data)
#     291
#     292     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     309
#     310         if self.keep_alive:
# --> 311             response = self._conn.request(method, url, body=body, headers=headers)
#     312             statuscode = response.status
#     313         else:
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     813                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814             )
# --> 815             return self.urlopen(
#     816                 method,
#     817                 url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     813                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814             )
# --> 815             return self.urlopen(
#     816                 method,
#     817                 url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     813                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814             )
# --> 815             return self.urlopen(
#     816                 method,
#     817                 url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785                 e = ProtocolError("Connection aborted.", e)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     590
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#     594         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=63104): Max retries exceeded with url: /session/37232eab157a0d2f6ec3ec54e390544e/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000024C6B0C8B50>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))

# %% [markdown]
# ## 6. 무한 스크롤
# 스크롤 내리기(자바스크립트)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url= 'https://naver.com'
driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

try:
    driver.get(url)
    driver.execute_script('window.scrollTo(0, 200)') # 자바스크립트 실행. 모니터 해상도 전달
    time.sleep(5)
    
except Exception as e:
    print(e)

finally:
    driver.close() # 브라우저 하나 종료
    driver.quit() # 브라우저 전체 종료
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\3988332286.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome('C:\\Users\\acorn\\Downloads\\chromedriver')

# %% [markdown]
# ## 7. 셀프 주유소 분석
# - 실제 셀프 주유소가 저렴한지에 대한 체크
# - 가장 저렴한 주유소
# - https://www.opinet.co.kr

# %% [markdown]
# ### (1) Data Crawling

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager # 크롬 버전 알아서 맞춰줌
from selenium.webdriver.chrome.service import Service

import time

# %%
url= 'https://www.opinet.co.kr/searRgSelect.do'
driver= webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get(url) # 메인페이지로 연결

# %% [markdown]
# #### 연습

# %%
#### 시 목록 가져오기
si_list_raw= driver.find_element(By.ID, 'SIDO_NM0')
si_list= si_list_raw.find_elements(By.TAG_NAME, 'option')
for i in si_list:
    print(i.get_attribute('value'))
# Out:
# 서울특별시
# 부산광역시
# 대구광역시
# 인천광역시
# 광주광역시
# 대전광역시
# 울산광역시
# 세종특별자치시
# 경기도
# 강원도
# 충청북도
# 충청남도
# 전라북도
# 전라남도
# 경상북도
# 경상남도
# 제주특별자치도

# %%
si_names=[i.get_attribute('value') for i in si_list]
si_names.remove('')
si_names
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
#### 시 선택하기
tag= driver.find_element(By.ID, 'SIDO_NM0')
tag.send_keys(si_names[0])

# %%
#### 구 목록 가져오기
gu_lists= driver.find_element(By.ID, 'SIGUNGU_NM0')
gu_names= [ i.get_attribute('value') for i in gu_lists.find_elements(By.TAG_NAME, 'option')]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
#### 구 선택하기
tag= driver.find_element(By.ID, 'SIGUNGU_NM0')
tag.send_keys(gu_names[0])

# %%
#### 조회 버튼 누르기
driver.find_element(By.ID, 'searRgSelect').click()

# %%
#### 엑셀 저장버튼 누르기
driver.find_element(By.ID, 'glopopd_excel').click()

# %% [markdown]
# #### 지역별(구별)로 주유소 정보를 엑셀 파일로 저장하기

# %%
from tqdm.notebook import tqdm

# %%
for gu in tqdm(gu_names):
    tag= driver.find_element(By.ID, 'SIGUNGU_NM0')
    tag.send_keys(gu)
    time.sleep(1)
    
    driver.find_element(By.ID, 'searRgSelect').click()
    time.sleep(1)
    
    driver.find_element(By.ID, 'glopopd_excel').click()
    time.sleep(1)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6092\3065462533.py in <module>
#       7     time.sleep(1)
#       8
# ----> 9     driver.find_element(By.ID, 'glopopd_excel').click()
#      10     time.sleep(1)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      92     def click(self) -> None:
#      93         """Clicks the element."""
# ---> 94         self._execute(Command.CLICK_ELEMENT)
#      95
#      96     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     402             params = {}
#     403         params["id"] = self._id
# --> 404         return self._parent.execute(command, params)
#     405
#     406     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a class="btn_type6_ex_save" href="javascript:fn_excel_download('os_btn');" id="glopopd_excel" title="새창열림:엑셀저장">...</a> is not clickable at point (287, 825). Other element would receive the click: <div id="mpopup_bg" style="position: absolute; z-index: 32001; top: 0px; left: 0px; width: 100%; height: 954px; margin: 0px; padding: 0px; border: 0px solid black; display: block;">...</div>
#   (Session info: chrome=111.0.5563.147)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0053DCE3]
# 	(No symbol) [0x004D39D1]
# 	(No symbol) [0x003E4DA8]
# 	(No symbol) [0x004152EA]
# 	(No symbol) [0x00413BBA]
# 	(No symbol) [0x00411EFB]
# 	(No symbol) [0x00411027]
# 	(No symbol) [0x00408D05]
# 	(No symbol) [0x0042AECC]
# 	(No symbol) [0x00408726]
# 	(No symbol) [0x0042B224]
# 	(No symbol) [0x0043D57C]
# 	(No symbol) [0x0042ACC6]
# 	(No symbol) [0x00406F68]
# 	(No symbol) [0x004080CD]
# 	GetHandleVerifier [0x007B3832+2506274]
# 	GetHandleVerifier [0x007E9794+2727300]
# 	GetHandleVerifier [0x007EE36C+2746716]
# 	GetHandleVerifier [0x005E6690+617600]
# 	(No symbol) [0x004DC712]
# 	(No symbol) [0x004E1FF8]
# 	(No symbol) [0x004E20DB]
# 	(No symbol) [0x004EC63B]
# 	BaseThreadInitThunk [0x74EC00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F07BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F07B8E+238]

# %% [markdown]
# ### (2) Data Definition

# %%
from glob import glob

# %%
station_files= glob('data/oil/지역*.*')

tmp_raw=[]
for f in station_files:
    tmp= pd.read_excel(f, header=2)
    tmp_raw.append(tmp)

# %%
#### 데이터 프레임으로 합치기
station_raw= pd.concat(tmp_raw)
station_raw
# index 중복 상태

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상호      453 non-null    object
#  1   주소      453 non-null    object
#  2   상표      453 non-null    object
#  3   전화번호    453 non-null    object
#  4   셀프여부    453 non-null    object
#  5   고급휘발유   453 non-null    object
#  6   휘발유     453 non-null    object
#  7   경유      453 non-null    object
#  8   실내등유    453 non-null    object
# dtypes: object(9)
# memory usage: 35.4+ KB

# %% [markdown]
# ### (3) Data Preprocessing

# %%
stations= pd.DataFrame({'oil_store':station_raw['상호'], '주소':station_raw['주소'],
             '가격':station_raw['휘발유'], '셀프':station_raw['셀프여부'], '상표':station_raw['상표']})
stations
# Out:
#                oil_store                            주소    가격 셀프      상표
# 0   재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1672  Y  현대오일뱅크
# 1                 구천면주유소         서울 강동구 구천면로 357 (암사동)  1684  N  현대오일뱅크
# 2      현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  1689  Y  현대오일뱅크
# 3       (주)소모에너지 신월셀프주유소        서울 강동구 양재대로 1323 (성내동)  1695  Y   GS칼텍스
# 4                방아다리주유소          서울 강동구 동남로 811 (명일동)  1695  Y   SK에너지
# ..                   ...                           ...   ... ..     ...
# 29                 대청주유소          서울 강남구 개포로 654 (일원동)  2246  N   SK에너지
# 30    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  2248  N  현대오일뱅크
# 31               SK논현주유소          서울 강남구 논현로 747 (논현동)  2345  N   SK에너지
# 32               갤러리아주유소               서울 강남구 압구정로 426  2362  N   SK에너지
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2598  N   GS칼텍스
#
# [453 rows x 5 columns]

# %% [markdown]
# #### '구' 파생변수 추가

# %%
stations['구']= stations['주소'].str.split(' ').str[1]
stations
# Out:
#                oil_store                            주소    가격 셀프      상표    구
# 0   재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1672  Y  현대오일뱅크  강동구
# 1                 구천면주유소         서울 강동구 구천면로 357 (암사동)  1684  N  현대오일뱅크  강동구
# 2      현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  1689  Y  현대오일뱅크  강동구
# 3       (주)소모에너지 신월셀프주유소        서울 강동구 양재대로 1323 (성내동)  1695  Y   GS칼텍스  강동구
# 4                방아다리주유소          서울 강동구 동남로 811 (명일동)  1695  Y   SK에너지  강동구
# ..                   ...                           ...   ... ..     ...  ...
# 29                 대청주유소          서울 강남구 개포로 654 (일원동)  2246  N   SK에너지  강남구
# 30    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  2248  N  현대오일뱅크  강남구
# 31               SK논현주유소          서울 강남구 논현로 747 (논현동)  2345  N   SK에너지  강남구
# 32               갤러리아주유소               서울 강남구 압구정로 426  2362  N   SK에너지  강남구
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2598  N   GS칼텍스  강남구
#
# [453 rows x 6 columns]

# %%
for add in stations['주소']:
    gu= add.split(' ')
    print(gu[1])

# %%
stations.iloc[300]
# Out:
# oil_store                     방화주유소
# 주소           서울 강서구 방화동로 58-2 (방화동)
# 가격                             1613
# 셀프                                Y
# 상표                            SK에너지
# 구                               강서구
# Name: 6, dtype: object

# %%
#### 가격 결측치 확인

stations['가격'].unique()
stations[stations['가격']=='-']
stations= stations[stations['가격']!='-']
stations['가격'].unique()
# Out:
# array([1672, 1684, 1689, 1695, 1726, 1736, 1755, 1758, 1796, 1798, 1848,
#        1978, '1635', '1645', '1659', '1668', '1677', '1685', '1695',
#        '1697', '1698', '1870', 1644, 1669, 1679, 1697, 1699, 1707, 1875,
#        1668, 1677, 1687, 1708, 1709, 1719, 1769, 1999, 1649, 1659, 1662,
#        1663, 1675, 1682, 1698, '1598', '1696', '1699', '1702', '1705',
#        '1710', '1715', '1717', '1719', '1735', '1736', '1745', '1749',
#        '1750', '1756', '1794', '1798', '1893', '2098', '2289', '2395',
#        1624, 1635, 1639, 1678, 1683, 1748, 1779, 1788, 1815, 1947, 1993,
#        2098, 2189, 1623, 1625, 1634, 1637, 1653, 1655, 1657, 1701, 1703,
#        1673, 1688, 1715, 1738, 1998, '1574', '1577', '1594', '1599',
#        '1619', '1620', '1629', '1639', '1644', '1647', '1682', '1687',
#        '1689', '1799', '1595', '1622', '1627', '1649', '1674', '1679',
#        '1703', '2038', '2090', '2099', '2145', '2199', 1658, 1665, 1852,
#        1877, 1910, 1911, 2068, 2110, 2179, 2297, 2629, '1654', '1657',
#        '1665', '1748', '1830', '2198', '2280', '2290', '2297', '1768',
#        '1833', '1850', '2048', '2247', '2439', '2644', 1627, 1645, 1574,
#        1610, 1612, 1613, 1614, 1615, 1617, 1647, 1666, 1667, 1696, 1712,
#        1716, 1725, 1730, 1778, 1741, 1756, '1624', '1625', '1653', '1684',
#        '1758', 1595, 1629, 1648, 1765, 1797, 1799, 2298, 1618, 1619, 1685,
#        1705, 1718, 1759, 1770, 1785, 1636, 1727, 1735, 1747, 1750, 1775,
#        1784, 1898, 1909, 1912, 1979, 2044, 2197, 2198, 2246, 2248, 2345,
#        2362, 2598], dtype=object)

# %%
#### 가격 정보를 숫자형으로 변환
stations['가격']= stations['가격'].astype(float)
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   oil_store  443 non-null    object
#  1   주소         443 non-null    object
#  2   가격         443 non-null    float64
#  3   셀프         443 non-null    object
#  4   상표         443 non-null    object
#  5   구          443 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 24.2+ KB
# C:\Users\acorn\AppData\Local\Temp\ipykernel_6092\163099685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations['가격']= stations['가격'].astype(float)

# %%
#### 인덱스 재조정
stations.reset_index(drop= True, inplace= True)

# %%
stations
# Out:
#                 oil_store                            주소      가격 셀프      상표  \
# 0    재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1672.0  Y  현대오일뱅크
# 1                  구천면주유소         서울 강동구 구천면로 357 (암사동)  1684.0  N  현대오일뱅크
# 2       현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  1689.0  Y  현대오일뱅크
# 3        (주)소모에너지 신월셀프주유소        서울 강동구 양재대로 1323 (성내동)  1695.0  Y   GS칼텍스
# 4                 방아다리주유소          서울 강동구 동남로 811 (명일동)  1695.0  Y   SK에너지
# ..                    ...                           ...     ... ..     ...
# 438                 대청주유소          서울 강남구 개포로 654 (일원동)  2246.0  N   SK에너지
# 439    (주)새서울네트웍스 제이제이주유소                서울 강남구 언주로 716  2248.0  N  현대오일뱅크
# 440               SK논현주유소          서울 강남구 논현로 747 (논현동)  2345.0  N   SK에너지
# 441               갤러리아주유소               서울 강남구 압구정로 426  2362.0  N   SK에너지
# 442        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2598.0  N   GS칼텍스
#
#        구
# 0    강동구
# 1    강동구
# 2    강동구
# 3    강동구
# 4    강동구
# ..   ...
# 438  강남구
# 439  강남구
# 440  강남구
# 441  강남구
# 442  강남구
#
# [443 rows x 6 columns]

# %% [markdown]
# ### (4) Data Visualization
# #### 1) 셀프 여부에 따른 가격 차이

# %%
stations.boxplot(by='셀프', column= '가격')
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프'>

# %% [markdown]
# #### 2) 주유소의 상표별로 얼마나 저렴한가?

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', data= stations, palette='Set3')
sns.swarmplot(x='상표', y='가격', data= stations, palette='Set3')
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\acorn\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='상표', ylabel='가격'>

# %% [markdown]
# #### 3) 구별 주유 가격 확인

# %%
#### 서울시에서 가장 가격이 비싼곳
high= stations.sort_values('가격', ascending=False).head(10)
high
# Out:
#           oil_store                      주소      가격 셀프     상표    구
# 273           서남주유소            서울 중구 통일로 30  2644.0  N  SK에너지   중구
# 239           서계주유소   서울 용산구  청파로 367 (청파동)  2629.0  N  GS칼텍스  용산구
# 442  (주)만정에너지 삼보주유소   서울 강남구 봉은사로 433 (삼성동)  2598.0  N  GS칼텍스  강남구
# 272           필동주유소    서울 중구 퇴계로 196 (필동2가)  2439.0  N  GS칼텍스   중구
# 96          양재최고주유소     서울 서초구 매헌로 72 (양재동)  2395.0  N  S-OIL  서초구
# 441         갤러리아주유소         서울 강남구 압구정로 426  2362.0  N  SK에너지  강남구
# 440         SK논현주유소    서울 강남구 논현로 747 (논현동)  2345.0  N  SK에너지  강남구
# 366           구로주유소   서울 구로구 구로동로 137 (구로동)  2298.0  N  GS칼텍스  구로구
# 238            한남지점  서울 용산구 한남대로21길 4 (한남동)  2297.0  N  SK에너지  용산구
# 237            에너비스    서울 용산구 한남대로 82 (한남동)  2297.0  N  SK에너지  용산구

# %%
#### 서울시에서 가장 가격이 싼곳
low= stations.sort_values('가격').head(10)
low
# Out:
#            oil_store                      주소      가격 셀프      상표     구
# 290  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  1574.0  Y  현대오일뱅크   강서구
# 287            목화주유소   서울 강서구 국회대로 251 (화곡동)  1574.0  Y   알뜰주유소   강서구
# 288           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1574.0  N   알뜰주유소   강서구
# 166           양천구주유소    서울 양천구 국회대로 275 (목동)  1574.0  Y   알뜰주유소   양천구
# 289           화곡역주유소    서울 강서구 강서로 154 (화곡동)  1574.0  Y   알뜰주유소   강서구
# 167            현대주유소  서울 양천구 남부순환로 372 (신월동)  1577.0  Y   S-OIL   양천구
# 168      형산석유(주)원주유소        서울 양천구 남부순환로 408  1594.0  N  현대오일뱅크   양천구
# 379           화랑대주유소          서울 노원구 화랑로 483  1595.0  Y  현대오일뱅크   노원구
# 347   (주)한미석유구로그린주유소   서울 구로구 구로중앙로 76 (구로동)  1595.0  Y   GS칼텍스   구로구
# 189       영등포제일셀프주유소        서울 영등포구 가마산로 379  1595.0  Y  현대오일뱅크  영등포구

# %% [markdown]
# #### 4) 구별 가격 평균값을 지도에 표시

# %%
gu_mean= stations.groupby('구').mean()
gu_mean.sort_values('가격')
# Out:
#                가격        lat         lng
# 구
# 강북구   1642.750000  37.632699  127.026265
# 도봉구   1645.312500  37.661858  127.038316
# 중랑구   1647.615385  37.593682  127.085404
# 성북구   1649.869565  37.602137  127.031597
# 양천구   1650.173913  37.526742  126.854457
# 금천구   1661.181818  37.461265  126.899869
# 광진구   1668.000000  37.553405  127.088327
# 서대문구  1670.066667  37.576198  126.935355
# 동대문구  1670.470588  37.582981  127.057218
# 노원구   1679.400000  37.638428  127.074139
# 은평구   1679.437500  37.607138  126.915754
# 강서구   1680.545455  37.554037  126.837024
# 송파구   1699.566667  37.498704  127.117733
# 동작구   1705.666667  37.495802  126.951303
# 관악구   1709.571429  37.479349  126.936985
# 영등포구  1721.000000  37.515808  126.906482
# 구로구   1722.350000  37.492982  126.867572
# 마포구   1724.166667  37.553390  126.926454
# 강동구   1759.142857  37.542493  127.140075
# 서초구   1780.233333  37.485267  127.016565
# 성동구   1786.187500  37.554299  127.047772
# 강남구   1916.500000  37.500132  127.056466
# 중구    2036.100000  37.560606  127.005211
# 종로구   2036.500000  37.594493  126.974015
# 용산구   2094.916667  37.538794  126.977518

# %%
import folium

# 구별로 표시되어있는 json 파일 이용
geo_path= 'data/seoul/skorea_municipalities_geo_simple_seoul.json'

# 지도 시작점
map= folium.Map(location=[37.5, 127], zoom_start=10)

# 지도에 표시
map.choropleth(geo_data= geo_path, data= gu_mean['가격'], key_on='feature.id',
              columns=[gu_mean.index, '가격'], fill_color='YlGn')
map
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\folium\folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e72dbd2f0d14a1a5800a1a052247fca4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e72dbd2f0d14a1a5800a1a052247fca4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e72dbd2f0d14a1a5800a1a052247fca4 = L.map(
#                 &quot;map_e72dbd2f0d14a1a5800a1a052247fca4&quot;,
#                 {
#                     center: [37.5, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2040d25b3664437dc6bac51e83803c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e72dbd2f0d14a1a5800a1a052247fca4);
#
#
#             var choropleth_896219ba426d25662e798546dc7aad87 = L.featureGroup(
#                 {}
#             ).addTo(map_e72dbd2f0d14a1a5800a1a052247fca4);
#
#
#         function geo_json_5786b13c5109d121f211d5c3af7d915b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5786b13c5109d121f211d5c3af7d915b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5786b13c5109d121f211d5c3af7d915b = L.geoJson(null, {
#                 onEachFeature: geo_json_5786b13c5109d121f211d5c3af7d915b_onEachFeature,
#
#                 style: geo_json_5786b13c5109d121f211d5c3af7d915b_styler,
#         });
#
#         function geo_json_5786b13c5109d121f211d5c3af7d915b_add (data) {
#             geo_json_5786b13c5109d121f211d5c3af7d915b
#                 .addData(data)
#                 .addTo(choropleth_896219ba426d25662e798546dc7aad87);
#         }
#             geo_json_5786b13c5109d121f211d5c3af7d915b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;: &quot;Songpa-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.05867359288398, 37.52629974922568], [127.0690698130372, 37.522279423505026], [127.0719146000724, 37.50224013587669], [127.11117085201238, 37.485708381512445], [127.1244

# %% [markdown]
# #### 5) 주유 가격 상/하위 10개씩을 지도에 표시

# %%
high
# Out:
#           oil_store                      주소      가격 셀프     상표    구
# 273           서남주유소            서울 중구 통일로 30  2644.0  N  SK에너지   중구
# 239           서계주유소   서울 용산구  청파로 367 (청파동)  2629.0  N  GS칼텍스  용산구
# 442  (주)만정에너지 삼보주유소   서울 강남구 봉은사로 433 (삼성동)  2598.0  N  GS칼텍스  강남구
# 272           필동주유소    서울 중구 퇴계로 196 (필동2가)  2439.0  N  GS칼텍스   중구
# 96          양재최고주유소     서울 서초구 매헌로 72 (양재동)  2395.0  N  S-OIL  서초구
# 441         갤러리아주유소         서울 강남구 압구정로 426  2362.0  N  SK에너지  강남구
# 440         SK논현주유소    서울 강남구 논현로 747 (논현동)  2345.0  N  SK에너지  강남구
# 366           구로주유소   서울 구로구 구로동로 137 (구로동)  2298.0  N  GS칼텍스  구로구
# 238            한남지점  서울 용산구 한남대로21길 4 (한남동)  2297.0  N  SK에너지  용산구
# 237            에너비스    서울 용산구 한남대로 82 (한남동)  2297.0  N  SK에너지  용산구

# %%
#### 주유소별 위도,경도 구하기    카카오 안됨!!!

import googlemaps

gmaps_key= 'AIzaSyCh05HAC0pdYWOKQC3g4ixDXkvKFmbwe_Y'
gmaps= googlemaps.Client(key= gmaps_key)

go_addr_lat=[]
go_addr_lng=[]

for name in list(high['주소']):
    place= gmaps.geocode(f"{name}",language='ko')[0]
    go_addr_lat.append(place['geometry']['location']['lat'])
    go_addr_lng.append(place['geometry']['location']['lng'])

# %%
#### 카카오로 하는법
import requests

url= 'https://dapi.kakao.com/v2/local/search/keyword.json?query={검색어}'
head= {'Authorization':'KakaoAK 652b6eec3ff39a3391e804677076be2a'}

lat=[]
lng=[]
for n in high.index:
    tmp_addr= high['주소'][n].split(' (')[0]
    url= 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(tmp_addr)
    lat.append(requests.get(url, header=head).json()['documents'][0]['x'])
    lng.append(requests.get(url, header=head).json()['documents'][0]['x'])

# %%
high['lat']= go_addr_lat
high['lng']= go_addr_lng
high
# Out:
#           oil_store                      주소      가격 셀프     상표    구        lat  \
# 273           서남주유소            서울 중구 통일로 30  2644.0  N  SK에너지   중구  37.558375
# 239           서계주유소   서울 용산구  청파로 367 (청파동)  2629.0  N  GS칼텍스  용산구  37.552329
# 442  (주)만정에너지 삼보주유소   서울 강남구 봉은사로 433 (삼성동)  2598.0  N  GS칼텍스  강남구  37.511521
# 272           필동주유소    서울 중구 퇴계로 196 (필동2가)  2439.0  N  GS칼텍스   중구  37.558773
# 96          양재최고주유소     서울 서초구 매헌로 72 (양재동)  2395.0  N  S-OIL  서초구  37.467158
# 441         갤러리아주유소         서울 강남구 압구정로 426  2362.0  N  SK에너지  강남구  37.526784
# 440         SK논현주유소    서울 강남구 논현로 747 (논현동)  2345.0  N  SK에너지  강남구  37.513679
# 366           구로주유소   서울 구로구 구로동로 137 (구로동)  2298.0  N  GS칼텍스  구로구  37.490960
# 238            한남지점  서울 용산구 한남대로21길 4 (한남동)  2297.0  N  SK에너지  용산구  37.534733
# 237            에너비스    서울 용산구 한남대로 82 (한남동)  2297.0  N  SK에너지  용산구  37.536041
#
#             lng
# 273  126.972094
# 239  126.968946
# 442  127.047172
# 272  126.994721
# 96   127.034715
# 441  127.043539
# 440  127.031712
# 366  126.883648
# 238  127.006095
# 237  127.006128

# %%
go_addr_lat=[]
go_addr_lng=[]

for name in list(low['주소']):
    place= gmaps.geocode(f"{name}",language='ko')[0]
    go_addr_lat.append(place['geometry']['location']['lat'])
    go_addr_lng.append(place['geometry']['location']['lng'])
    
low['lat']= go_addr_lat
low['lng']= go_addr_lng
low
# Out:
#            oil_store                      주소      가격 셀프      상표     구  \
# 290  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  1574.0  Y  현대오일뱅크   강서구
# 287            목화주유소   서울 강서구 국회대로 251 (화곡동)  1574.0  Y   알뜰주유소   강서구
# 288           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1574.0  N   알뜰주유소   강서구
# 166           양천구주유소    서울 양천구 국회대로 275 (목동)  1574.0  Y   알뜰주유소   양천구
# 289           화곡역주유소    서울 강서구 강서로 154 (화곡동)  1574.0  Y   알뜰주유소   강서구
# 167            현대주유소  서울 양천구 남부순환로 372 (신월동)  1577.0  Y   S-OIL   양천구
# 168      형산석유(주)원주유소        서울 양천구 남부순환로 408  1594.0  N  현대오일뱅크   양천구
# 379           화랑대주유소          서울 노원구 화랑로 483  1595.0  Y  현대오일뱅크   노원구
# 347   (주)한미석유구로그린주유소   서울 구로구 구로중앙로 76 (구로동)  1595.0  Y   GS칼텍스   구로구
# 189       영등포제일셀프주유소        서울 영등포구 가마산로 379  1595.0  Y  현대오일뱅크  영등포구
#
#            lat         lng
# 290  37.549163  126.846996
# 287  37.530040  126.862983
# 288  37.531580  126.856052
# 166  37.530315  126.865517
# 289  37.540719  126.841530
# 167  37.533873  126.829262
# 168  37.531139  126.830982
# 379  37.619577  127.080630
# 347  37.496306  126.888444
# 189  37.502348  126.899503

# %%
map= folium.Map([37.5,127], zoom_start=10)

for i in high.index:
    folium.Marker(location=[high['lat'][i],high['lng'][i]],    #dataframe[열][행]
                  icon=folium.Icon(color='red', icon='star'),
                 popup= high['oil_store'][i]).add_to(map)
    
for i in low.index:
    folium.Marker(location=[low['lat'][i],low['lng'][i]],    #dataframe[열][행]
                  icon=folium.Icon(color='blue', icon='star'),
                 popup= low['oil_store'][i]).add_to(map)
    
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86d5dc51ec71cf17d07d7ca5c6796c45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86d5dc51ec71cf17d07d7ca5c6796c45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86d5dc51ec71cf17d07d7ca5c6796c45 = L.map(
#                 &quot;map_86d5dc51ec71cf17d07d7ca5c6796c45&quot;,
#                 {
#                     center: [37.5, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a99db9579e135244ad023d03d89e263f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86d5dc51ec71cf17d07d7ca5c6796c45);
#
#
#             var marker_ef99d9a1a2d52ecc008e13da0767eff9 = L.marker(
#                 [37.5583749, 126.9720939],
#                 {}
#             ).addTo(map_86d5dc51ec71cf17d07d7ca5c6796c45);
#
#
#             var icon_656363c28b87888c5bce1c4738170dc5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef99d9a1a2d52ecc008e13da0767eff9.setIcon(icon_656363c28b87888c5bce1c4738170dc5);
#
#
#         var popup_d3f793018b4a8fe4ec636a32ff92bc00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dc968d4a24d4966fa843e61e0c2c6a1 = $(`&lt;div id=&quot;html_1dc968d4a24d4966fa843e61e0c2c6a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서남주유소&lt;/div&gt;`)[0];
#                 popup_d3f793018b4a8fe4ec636a32ff92bc00.setContent(html_1dc968d4a24d4966fa843e61e0c2c6a1);
#
#
#
#         marker_ef99d9a1a2d52ecc008e13da0767eff9.bindPopup(popup_d3f793018b4a8fe4ec636a32ff92bc00)
#         ;
#
#
#
#
#             var marker_41c2a24570ab69f6f01e8ec15a46ad4e = L.marker(
#                 [37.5523286, 126.9689462],
#                 {}
#             ).addTo(map_86d5dc51ec71cf17d07d7ca5c6796c45);
#
#
#             var icon_2578fccde6e8668a1bf1c5615b58cc8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_41c2a24570ab69f6f01e8ec15a46ad4e.setIcon(icon_2578fccde6e8668a1bf1c5615b58cc8d);
#
#
#         var popup_9522d0291a95a1b26bbd108653760800 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ca60eee99b887252ed54cfd03dccfe3 = $(`&lt;div id=&quot;html_8ca60eee99b887252ed54cfd03dccfe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서계주유소&lt;/div&gt;`)[0];
#                 popup_9522d0291a95a1b26bbd108653760800.setContent(html_8ca60eee99b887252ed54cfd03dccfe3);
#
#
#
#         marker_41c2a24570ab69f6f01e8ec15a46ad4e.bindPopup(popup_9522d0291a95a1b26bbd108653760800)
#         ;
#
#
#
#
#             var marker_d98130f26818c18770cff7ff1a2fcfd6 = L.marker(
#                 [37.5115207, 127.0471716],
#                 {}
#             ).addTo(map_86d5dc51ec71cf17d07d7ca5c6796c45);
#
#
#             var icon_d0cb8dded93a98a7a3619b109612ac96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d98130f26818c18770cff7ff1a2fcfd6.setIcon(icon_d0cb8dded93a98a7a3619b109612ac96);
#
#
#         var popup_d6765c8084eaef459e76686217ed3231 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27ad71c13627dfaf403e1191dbd334f3 = $(`&lt;div id=&quot;html_27ad71c13627dfaf403e1191dbd334f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(주)만정에너지 삼보주유소&lt;/div&gt;`)[0];
#                 popup_d6765c8084eaef459e76686217ed3231.setContent(html_27ad71c13627dfaf403e1191dbd334f3);
#
#
#
#         marker_d98130f26818c18770cff7ff1a2fcfd6.bindPopup(popup_d6765c8084eaef459e76686217ed3231)
#         ;
#
#
#
#
#             var marker_e7848be881677c0c580a6bf5536badd4 = L.marker(
#                 [37.5587734, 126.9947209],
#                 {}
#             ).addTo(map_86d5dc51ec71cf17d07d7ca5c6796c45);
#
#
#             var icon_d5ca2a8158d07776c2bff8e0fcf2bf1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot

# %%
map= folium.Map([37.5,127], zoom_start=10)

for i in low.index:
    folium.Marker(location=[low['lat'][i],low['lng'][i]],    #dataframe[열][행]
                  icon=folium.Icon(color='red', icon='star'),
                 popup= low['oil_store'][i]).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e62d85c7e9ee7a4006e28d5b0609375d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e62d85c7e9ee7a4006e28d5b0609375d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e62d85c7e9ee7a4006e28d5b0609375d = L.map(
#                 &quot;map_e62d85c7e9ee7a4006e28d5b0609375d&quot;,
#                 {
#                     center: [37.5, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9990b071050b53963e00e215847dbdf8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e62d85c7e9ee7a4006e28d5b0609375d);
#
#
#             var marker_727b13f022baa7df3929002bd99843b0 = L.marker(
#                 [37.549163, 126.8469964],
#                 {}
#             ).addTo(map_e62d85c7e9ee7a4006e28d5b0609375d);
#
#
#             var icon_fb9a78960afa5d1ae0a83f65b7d203a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_727b13f022baa7df3929002bd99843b0.setIcon(icon_fb9a78960afa5d1ae0a83f65b7d203a3);
#
#
#         var popup_9510445967ddfe5b983c21c06f4e9da2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d108341920b80aaf43c213e84be8a28 = $(`&lt;div id=&quot;html_1d108341920b80aaf43c213e84be8a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이케이에너지(주) 강서주유소&lt;/div&gt;`)[0];
#                 popup_9510445967ddfe5b983c21c06f4e9da2.setContent(html_1d108341920b80aaf43c213e84be8a28);
#
#
#
#         marker_727b13f022baa7df3929002bd99843b0.bindPopup(popup_9510445967ddfe5b983c21c06f4e9da2)
#         ;
#
#
#
#
#             var marker_002ed638dab9480c492028e5f0dee24a = L.marker(
#                 [37.5300403, 126.8629825],
#                 {}
#             ).addTo(map_e62d85c7e9ee7a4006e28d5b0609375d);
#
#
#             var icon_e911c28b5eab55421154aa898a749945 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_002ed638dab9480c492028e5f0dee24a.setIcon(icon_e911c28b5eab55421154aa898a749945);
#
#
#         var popup_23ed9e1938099cc075a7fe7b99722b3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3d541bbc180e16bf6ef2cc3922ce603 = $(`&lt;div id=&quot;html_e3d541bbc180e16bf6ef2cc3922ce603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;목화주유소&lt;/div&gt;`)[0];
#                 popup_23ed9e1938099cc075a7fe7b99722b3c.setContent(html_e3d541bbc180e16bf6ef2cc3922ce603);
#
#
#
#         marker_002ed638dab9480c492028e5f0dee24a.bindPopup(popup_23ed9e1938099cc075a7fe7b99722b3c)
#         ;
#
#
#
#
#             var marker_7d0777cb78b37e754ae5d99643bb2311 = L.marker(
#                 [37.5315796, 126.8560524],
#                 {}
#             ).addTo(map_e62d85c7e9ee7a4006e28d5b0609375d);
#
#
#             var icon_d8a96cbb603b5a4f210a445e77053568 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d0777cb78b37e754ae5d99643bb2311.setIcon(icon_d8a96cbb603b5a4f210a445e77053568);
#
#
#         var popup_5e9213ac912c54f75d24eb3fe0449878 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ab7c4585b7d9eb77523687d766c0104 = $(`&lt;div id=&quot;html_5ab7c4585b7d9eb77523687d766c0104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;뉴신정주유소&lt;/div&gt;`)[0];
#                 popup_5e9213ac912c54f75d24eb3fe0449878.setContent(html_5ab7c4585b7d9eb77523687d766c0104);
#
#
#
#         marker_7d0777cb78b37e754ae5d99643bb2311.bindPopup(popup_5e9213ac912c54f75d24eb3fe0449878)
#         ;
#
#
#
#
#             var marker_2fa3fb5654bb373fadb0eecae40f7dd3 = L.marker(
#                 [37.5303149, 126.8655168],
#                 {}
#             ).addTo(map_e62d85c7e9ee7a4006e28d5b0609375d);
#
#
#             var icon_fd1dbf8bc737451b77ca57623afe5d85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quo
